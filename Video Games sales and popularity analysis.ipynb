# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
game=pd.read_csv("vgsales.csv")#Displaying all games
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gameR=game[game['Genre']=='Sports']
gameR
# Out:
#         Rank                           Name Platform    Year   Genre  \
# 0          1                     Wii Sports      Wii  2006.0  Sports
# 3          4              Wii Sports Resort      Wii  2009.0  Sports
# 13        14                        Wii Fit      Wii  2007.0  Sports
# 14        15                   Wii Fit Plus      Wii  2009.0  Sports
# 77        78                        FIFA 16      PS4  2015.0  Sports
# ...      ...                            ...      ...     ...     ...
# 16576  16579              Rugby Challenge 3     XOne  2016.0  Sports
# 16578  16581  Outdoors Unleashed: Africa 3D      3DS  2011.0  Sports
# 16579  16582              PGA European Tour      N64  2000.0  Sports
# 16581  16584                      Fit & Fun      Wii  2011.0  Sports
# 16587  16590       Mezase!! Tsuri Master DS       DS  2009.0  Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#2346 games belong sports category

# %%
game['Platform'].drop_duplicates()
# Out:
# 0         Wii
# 1         NES
# 4          GB
# 6          DS
# 15       X360
# 16        PS3
# 17        PS2
# 18       SNES
# 25        GBA
# 32        3DS
# 33        PS4
# 46        N64
# 52         PS
# 79         XB
# 83         PC
# 89       2600
# 90        PSP
# 101      XOne
# 107        GC
# 108      WiiU
# 143       GEN
# 637        DC
# 713       PSV
# 888       SAT
# 1261      SCD
# 3931       WS
# 6681       NG
# 9223     TG16
# 12635     3DO
# 13525      GG
# 14556    PCFX
# Name: Platform, dtype: object

# %%
game['Platform'].drop_duplicates().count()
# Out:
# 31

# %%
#Hence there are 31 kinds of platforms where different games can be played

# %%
gameS=game[game['Genre']=='Shooter']
gameS
# Out:
#         Rank                                               Name Platform  \
# 9         10                                          Duck Hunt      NES
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# ...      ...                                                ...      ...
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16577  16580                                          Damnation       PC
# 16585  16588                                             Breach       PC
# 16594  16597                      Men in Black II: Alien Escape       GC
#
#          Year    Genre    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#1310 shooting games
gameS[gameS['Platform']=='PC']
# Out:
#         Rank                                               Name Platform  \
# 281      282                                          Half-Life       PC
# 353      354                             Doom II: Hell on Earth       PC
# 533      534                                      Battlefield 3       PC
# 665      667                                        Half-Life 2       PC
# 874      876                             Star Wars: Dark Forces       PC
# ...      ...                                                ...      ...
# 16339  16342                         Command & Conquer Renegade       PC
# 16433  16436                             Clive Barker's Jericho       PC
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16577  16580                                          Damnation       PC
# 16585  16588                                             Breach       PC
#
#          Year    Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#out of 1310 shoooting games 148 could be played on PC

# %%
gameS[gameS['Platform']=='X360']
# Out:
#         Rank                                 Name Platform    Year    Genre  \
# 29        30       Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31        32              Call of Duty: Black Ops     X360  2010.0  Shooter
# 35        36           Call of Duty: Black Ops II     X360  2012.0  Shooter
# 36        37       Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 43        44                               Halo 3     X360  2007.0  Shooter
# ...      ...                                  ...      ...     ...      ...
# 16205  16208                            Caladrius     X360  2013.0  Shooter
# 16229  16232          Brothers in Arms: Furious 4     X360     NaN  Shooter
# 16263  16266   Mamoru-kun wa Norowarete Shimatta!     X360  2009.0  Shooter
# 16440  16443           Bullet Soul: Tama Tamashii     X360  2011.0  Shooter
# 16476  16479  DoDonPachi Daifukkatsu: Black Label     X360  2011.0  Shooter
#
# ...

# %%
#203 shooting games can be played on X360 platform

# %%
gameS[gameS['Platform']=='3DS']
# Out:
#         Rank                                               Name Platform  \
# 2197    2199                                     Star Fox 64 3D      3DS
# 11338  11340                                       Nano Assault      3DS
# 11893  11895                                      E.X. Troopers      3DS
# 11921  11923                                   Dream Trigger 3D      3DS
# 12411  12413  SpongeBob SquarePants: Plankton's Robotic Revenge      3DS
# 13405  13407                             Centipede: Infestation      3DS
# 15279  15282                      Heavy Fire: The Chosen Few 3D      3DS
#
#          Year    Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 2197   2011.0  Shooter               Nintendo      0.48      0.27      0.13
# 11338  2011.0  Shooter  Majesco Entertainment      0.08      0.00      0.00
# 11893  2012.0  Shooter                 Capcom      0.00      0.00      0.07
# 11921     NaN  Shooter            D3Publisher      0.04      0.02      0.00
# ...

# %%
#Only Seven shooting games are available on 3DS platform

# %%
gameS[gameS['Publisher']=='Activision']
# Out:
#         Rank                                               Name Platform  \
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# 35        36                         Call of Duty: Black Ops II     X360
# ...      ...                                                ...      ...
# 15605  15608                        James Bond 007: Blood Stone       PC
# 15804  15807               Call of Duty: Modern Warfare Trilogy     X360
# 15895  15898                        Enemy Territory: Quake Wars       PC
# 16334  16337          Greg Hastings' Tournament Paintball Max'd      PS2
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
#
#          Year    Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#159 games are published by Activision

# %%
gameS[gameS['Publisher']=='Nintendo']
# Out:
#         Rank                                Name Platform    Year    Genre  \
# 9         10                           Duck Hunt      NES  1984.0  Shooter
# 84        85                       GoldenEye 007      N64  1997.0  Shooter
# 206      207            Link's Crossbow Training      Wii  2007.0  Shooter
# 235      236                            Splatoon     WiiU  2015.0  Shooter
# 296      297                         Star Fox 64      N64  1997.0  Shooter
# 472      473                            Star Fox     SNES  1993.0  Shooter
# 519      520                       Metroid Prime       GC  2002.0  Shooter
# 955      957         Metroid Prime 3: Corruption      Wii  2007.0  Shooter
# 1108    1110                       Super Scope 6     SNES  1991.0  Shooter
# 1476    1478             Metroid Prime 2: Echoes       GC  2004.0  Shooter
# 1560    1562                       Hogan's Alley      NES  1984.0  Shooter
# ...

# %%
gameS[gameS['Publisher']=='Nintendo'].count()
# Out:
# Rank            26
# Name            26
# Platform        26
# Year            24
# Genre           26
# Publisher       26
# NA_Sales        26
# EU_Sales        26
# JP_Sales        26
# Other_Sales     26
# Global_Sales    26
# dtype: int64

# %%
#only 26 shooting games are launched by Nintendo

# %%
gameS.sort_values('Rank')
# Out:
#         Rank                                               Name Platform  \
# 9         10                                          Duck Hunt      NES
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# ...      ...                                                ...      ...
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16577  16580                                          Damnation       PC
# 16585  16588                                             Breach       PC
# 16594  16597                      Men in Black II: Alien Escape       GC
#
#          Year    Genre    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#the most popular shooting game is duck hunt as per the data( on NES platform )

# %%
gameS[gameS['Publisher']=='Activision'].sort_values('Rank')#sorting Activision shooting  games according to Their ranks
# Out:
#         Rank                                               Name Platform  \
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# 35        36                         Call of Duty: Black Ops II     X360
# ...      ...                                                ...      ...
# 15605  15608                        James Bond 007: Blood Stone       PC
# 15804  15807               Call of Duty: Modern Warfare Trilogy     X360
# 15895  15898                        Enemy Territory: Quake Wars       PC
# 16334  16337          Greg Hastings' Tournament Paintball Max'd      PS2
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
#
#          Year    Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#We will look on most popular Shooter PC GAME and perform analysis for the same.

# %%
gameS[gameS['Platform']=='PC'].sort_values('Rank')
# Out:
#         Rank                                               Name Platform  \
# 281      282                                          Half-Life       PC
# 353      354                             Doom II: Hell on Earth       PC
# 533      534                                      Battlefield 3       PC
# 665      667                                        Half-Life 2       PC
# 874      876                             Star Wars: Dark Forces       PC
# ...      ...                                                ...      ...
# 16339  16342                         Command & Conquer Renegade       PC
# 16433  16436                             Clive Barker's Jericho       PC
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16577  16580                                          Damnation       PC
# 16585  16588                                             Breach       PC
#
#          Year    Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#The most popular pc game is Half life as per the data given above

# %%
gameS[gameS['Platform']=='PC'].head(10)
# Out:
#       Rank                            Name Platform    Year    Genre  \
# 281    282                       Half-Life       PC  1997.0  Shooter
# 353    354          Doom II: Hell on Earth       PC  1994.0  Shooter
# 533    534                   Battlefield 3       PC  2011.0  Shooter
# 665    667                     Half-Life 2       PC  2004.0  Shooter
# 874    876          Star Wars: Dark Forces       PC  1994.0  Shooter
# 1037  1039  Call of Duty: Modern Warfare 3       PC  2011.0  Shooter
# 1126  1128         Call of Duty: Black Ops       PC     NaN  Shooter
# 1217  1219      Call of Duty: Black Ops II       PC  2012.0  Shooter
# 1386  1388                   Battlefield 4       PC  2013.0  Shooter
# 1769  1771  Call of Duty 4: Modern Warfare       PC  2007.0  Shooter
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 281        Vivendi Games      4.03      0.00      0.09         0.00
# 353   Virgin Interactive      2.05      1.40      0.00         0.16
# ...

# %%
print("Most popular Shooting PC games of all time.............")#top Ten
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Global_Sales",y="Name",data=gameS[gameS['Platform']=='PC'].head(10),hue='Name')
plt.show()
# Out:
# Most popular Shooting PC games of all time.............

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Global_Sales",y="Name",data=gameS[gameS['Platform']=='PC'].head(10),color='Green')
plt.show()

# %%
gameS[gameS['Platform']=='PS4'].sort_values('Rank')
# Out:
#         Rank                                               Name Platform  \
# 33        34                          Call of Duty: Black Ops 3      PS4
# 92        93                       Star Wars Battlefront (2015)      PS4
# 93        94                     Call of Duty: Advanced Warfare      PS4
# 154      155                                            Destiny      PS4
# 271      272                         Uncharted 4: A Thief's End      PS4
# 295      296                                          Far Cry 4      PS4
# 349      350                               Call of Duty: Ghosts      PS4
# 351      352                          Tom Clancy's The Division      PS4
# 386      387                                      Battlefield 4      PS4
# 593      594                              Killzone: Shadow Fall      PS4
# 758      760                    Tom Clancy's Rainbow Six: Siege      PS4
# 797      799                              Battlefield: Hardline      PS4
# ...

# %%
gameS[gameS['Platform']=='PS4'].count()
# Out:
# Rank            34
# Name            34
# Platform        34
# Year            34
# Genre           34
# Publisher       34
# NA_Sales        34
# EU_Sales        34
# JP_Sales        34
# Other_Sales     34
# Global_Sales    34
# dtype: int64

# %%
#34 Shooting games on PS4

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Global_Sales",y="Name",data=gameS[gameS['Platform']=='PS4'].head(15),hue='Name')
plt.show()

# %%
#Highest global sales for COD:Black Ops 3 and it is the top rated game in PS4 Platform in terms of shooting games

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Global_Sales",y="Name",data=gameS[gameS['Platform']=='PS4'].head(15),color='Black')
plt.show()

# %%
game.sort_values('Rank')
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game.head(16)
# Out:
#     Rank                         Name Platform    Year         Genre  \
# 0      1                   Wii Sports      Wii  2006.0        Sports
# 1      2            Super Mario Bros.      NES  1985.0      Platform
# 2      3               Mario Kart Wii      Wii  2008.0        Racing
# 3      4            Wii Sports Resort      Wii  2009.0        Sports
# 4      5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5      6                       Tetris       GB  1989.0        Puzzle
# 6      7        New Super Mario Bros.       DS  2006.0      Platform
# 7      8                     Wii Play      Wii  2006.0          Misc
# 8      9    New Super Mario Bros. Wii      Wii  2009.0      Platform
# 9     10                    Duck Hunt      NES  1984.0       Shooter
# 10    11                   Nintendogs       DS  2005.0    Simulation
# 11    12                Mario Kart DS       DS  2005.0        Racing
# 12    13  Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing
# ...

# %%
game[game['Platform']=='Wii'].sort_values('Rank')
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
#1325 games on wii platform.
#Wii sports is most popular with global sales of 82.74

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Global_Sales",y="Name",data=game[game['Platform']=='Wii'].head(15),hue='Name')
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})#top 15 games based on rank and global sales
sns.lineplot(x="Global_Sales",y="Name",data=game[game['Platform']=='Wii'].head(15),color='Green')
plt.show()

# %%
sns.pairplot(data=game)
plt.show()

# %%
sns.pairplot(data=gameR)
plt.show()

# %%
sns.pairplot(data=gameR[gameR['Publisher']=='Electronic Arts'])
plt.show()

# %%
game['Genre'].drop_duplicates()
# Out:
# 0            Sports
# 1          Platform
# 2            Racing
# 4      Role-Playing
# 5            Puzzle
# 7              Misc
# 9           Shooter
# 10       Simulation
# 16           Action
# 39         Fighting
# 50        Adventure
# 165        Strategy
# Name: Genre, dtype: object

# %%
game['Genre'].drop_duplicates().count()#tota 12 types of  genres
# Out:
# 12

# %%
game['Platform'].drop_duplicates().count()#31 types of platforms
# Out:
# 31

# %%
game[game['Year']>2005]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# ...      ...                                                ...      ...
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16592  16595                                           Plushees       DS
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
#
#          Year         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#10214 games released after 2005

# %%
game[game['Year']>2015]
# Out:
#         Rank                                               Name Platform  \
# 221      222                                            FIFA 17      PS4
# 271      272                         Uncharted 4: A Thief's End      PS4
# 351      352                          Tom Clancy's The Division      PS4
# 770      772                                    Far Cry: Primal      PS4
# 845      847                          Tom Clancy's The Division     XOne
# ...      ...                                                ...      ...
# 16562  16565                                       Mighty No. 9     XOne
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16570  16573                      Farming 2017 - The Simulation      PS4
# 16576  16579                                  Rugby Challenge 3     XOne
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year       Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
#348 released after 2015

# %%
game[game['Year']>2019]
# Out:
#       Rank                    Name Platform    Year       Genre Publisher  \
# 5957  5959  Imagine: Makeup Artist       DS  2020.0  Simulation   Ubisoft
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 5957      0.27       0.0       0.0         0.02          0.29

# %%
game[game['Year']>2017]
# Out:
#       Rank                    Name Platform    Year       Genre Publisher  \
# 5957  5959  Imagine: Makeup Artist       DS  2020.0  Simulation   Ubisoft
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 5957      0.27       0.0       0.0         0.02          0.29

# %%
game2005=game[game['Year']>2015] #games released after 2015
game2005[game2005['Publisher']=='Electronic Arts']
# Out:
#         Rank                                  Name Platform    Year     Genre  \
# 221      222                               FIFA 17      PS4  2016.0    Sports
# 1224    1226                               FIFA 17     XOne  2016.0    Sports
# 1628    1630                         Madden NFL 17      PS4  2016.0    Sports
# 2342    2344                       EA Sports UFC 2      PS4  2016.0    Sports
# 2505    2507                         Madden NFL 17     XOne  2016.0    Sports
# 4350    4352  Plants vs. Zombies: Garden Warfare 2      PS4  2016.0   Shooter
# 4430    4432  Plants vs. Zombies: Garden Warfare 2     XOne  2016.0   Shooter
# 4820    4822                       EA Sports UFC 2     XOne  2016.0    Sports
# 5056    5058                               FIFA 17      PS3  2016.0    Sports
# 5661    5663                Mirror's Edge Catalyst      PS4  2016.0  Platform
# 7575    7577                                NHL 17      PS4  2016.0    Sports
# ...

# %%
game2005[game2005['Publisher']=='Electronic Arts'].count()
# Out:
# Rank            20
# Name            20
# Platform        20
# Year            20
# Genre           20
# Publisher       20
# NA_Sales        20
# EU_Sales        20
# JP_Sales        20
# Other_Sales     20
# Global_Sales    20
# dtype: int64

# %%
game2005
# Out:
#         Rank                                               Name Platform  \
# 221      222                                            FIFA 17      PS4
# 271      272                         Uncharted 4: A Thief's End      PS4
# 351      352                          Tom Clancy's The Division      PS4
# 770      772                                    Far Cry: Primal      PS4
# 845      847                          Tom Clancy's The Division     XOne
# ...      ...                                                ...      ...
# 16562  16565                                       Mighty No. 9     XOne
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16570  16573                      Farming 2017 - The Simulation      PS4
# 16576  16579                                  Rugby Challenge 3     XOne
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year       Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
game2005['Name'].drop_duplicates()
# Out:
# 221                                                FIFA 17
# 271                             Uncharted 4: A Thief's End
# 351                              Tom Clancy's The Division
# 770                                        Far Cry: Primal
# 1026                                             Overwatch
#                                ...
# 16474                    Total War Attila: Tyrants & Kings
# 16550    God Eater Off Shot: Tachibana Sakuya-hen Twin ...
# 16555                Codename: Panzers Complete Collection
# 16570                        Farming 2017 - The Simulation
# 16589    Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...
# Name: Name, Length: 212, dtype: object

# %%
game2005['Name'].drop_duplicates().count()
# Out:
# 212

# %%
#Hence 212 games were released after 2015

# %%
game2005E=game2005[game2005['Publisher']=='Electronic Arts']#games realeased by electronic arts after 2015
game2005E
# Out:
#         Rank                                  Name Platform    Year     Genre  \
# 221      222                               FIFA 17      PS4  2016.0    Sports
# 1224    1226                               FIFA 17     XOne  2016.0    Sports
# 1628    1630                         Madden NFL 17      PS4  2016.0    Sports
# 2342    2344                       EA Sports UFC 2      PS4  2016.0    Sports
# 2505    2507                         Madden NFL 17     XOne  2016.0    Sports
# 4350    4352  Plants vs. Zombies: Garden Warfare 2      PS4  2016.0   Shooter
# 4430    4432  Plants vs. Zombies: Garden Warfare 2     XOne  2016.0   Shooter
# 4820    4822                       EA Sports UFC 2     XOne  2016.0    Sports
# 5056    5058                               FIFA 17      PS3  2016.0    Sports
# 5661    5663                Mirror's Edge Catalyst      PS4  2016.0  Platform
# 7575    7577                                NHL 17      PS4  2016.0    Sports
# ...

# %%
game2005E['Name'].drop_duplicates().count()
# Out:
# 7

# %%
#7 games are launched by electronic Arts after 2015

# %%
game2005A=game2005[game2005['Publisher']=='Activision']
game2005A
# Out:
#         Rank                                               Name Platform  \
# 1026    1028                                          Overwatch      PS4
# 2444    2446                                          Overwatch     XOne
# 4509    4511                                          Overwatch       PC
# 6087    6089                          World of Warcraft: Legion       PC
# 11841  11843  Teenage Mutant Ninja Turtles: Mutants in Manha...      PS4
# 12523  12525                            Destiny: The Collection      PS4
# 12930  12932  Teenage Mutant Ninja Turtles: Mutants in Manha...      PS3
# 13994  13996                            Destiny: The Collection     XOne
# 14186  14188  Teenage Mutant Ninja Turtles: Mutants in Manha...     XOne
# 14482  14485  Teenage Mutant Ninja Turtles: Mutants in Manha...     X360
# 14680  14683                                Ghostbusters (2016)      PS4
# 14913  14916                                Ghostbusters (2016)     XOne
# ...

# %%
game2005A['Name'].drop_duplicates() .count()
# Out:
# 6

# %%
#Hence 6 games are released by Activision after 2015
